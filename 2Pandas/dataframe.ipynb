# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt

# %%
import webbrowser

# %%
website='https://en.wikipedia.org/wiki/List_of_all-time_NFL_win%E2%80%93loss_records'

# %%
webbrowser.open(website)
# Out:
# True

# %%
nf1_frame = pd.read_clipboard(sep='\t', quotechar='"', quoting=0)

# %%
nf1_frame
# Out:
#     Rank                    Team     GP  Won  Lost Tied[c]   Pct.  \
# 0      1          Dallas Cowboys    981  562   413   6 (0)  0.576
# 1      2       Green Bay Packers  1,435  799   598  38 (8)  0.572
# 2      3        Baltimore Ravens    451  256   194       1  0.569
# 3      4           Chicago Bears  1,469  793   634  42 (1)  0.556
# 4      5    New England Patriots    983  541   433   9 (0)  0.555
# 5      6          Miami Dolphins    899  496   399   4 (1)  0.554
# 6      7      Kansas City Chiefs    983  532   439  12 (4)  0.548
# 7      8       Minnesota Vikings    969  523   435  11 (4)  0.546
# 8      9  San Francisco 49ers[b]  1,101  586   501  14 (3)  0.539
# 9     10     Pittsburgh Steelers  1,271  671   578  22 (4)  0.537
# 10    11         New York Giants  1,404  721   649  34 (4)  0.526
# 11    12   Indianapolis Colts[d]  1,065  556   501   8 (2)  0.526
# 12    13          Denver Broncos    983  508   465  10 (4)  0.522
# ...

# %%
nf1_frame.columns
# Out:
# Index(['Rank', 'Team', 'GP', 'Won', 'Lost', 'Tied[c]', 'Pct.',
#        'First NFL season', 'Division'],
#       dtype='object')

# %%
row_index = 3  # Example index, zero-based indexing
row_data = nf1_frame.iloc[row_index]

print("Row data:")
print(row_data)
# Out:
# Row data:
# Rank                            4
# Team                Chicago Bears
# GP                          1,469
# Won                           793
# Lost                          634
# Tied[c]                    42 (1)
# Pct.                        0.556
# First NFL season             1920
# Division                NFC North
# Name: 3, dtype: object

# %%
data={'city': ['SF','LA','NYC'],'population': [1500000,2000000,1200000]}

# %%
data1=pd.DataFrame(data)

# %%
data1
# Out:
#   city  population
# 0   SF     1500000
# 1   LA     2000000
# 2  NYC     1200000

# %%
website1 = 'https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html'
webbrowser.open(website1)
# Out:
# True

# %%
plt.figure(figsize=(8, 6))  

plt.bar(data['city'], data['population'], color='skyblue')

plt.xlabel('City')
plt.ylabel('Population')
plt.title('Population by City')

plt.show()
