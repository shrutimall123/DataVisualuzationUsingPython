# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
df = pd.read_csv('Renting.csv')

# %%
df.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# hum           0
# windspeed     0
# popularity    0
# casual        0
# registered    0
# Demand        0
# dtype: int64

# %%
df
# Out:
#        instant      dteday  season  hr        holiday   weekday  \
# 0            1  01/01/2011  Winter   0  Not a Holiday  Saturday
# 1            2  01/01/2011  Winter   1  Not a Holiday  Saturday
# 2            3  01/01/2011  Winter   2  Not a Holiday  Saturday
# 3            4  01/01/2011  Winter   3  Not a Holiday  Saturday
# 4            5  01/01/2011  Winter   4  Not a Holiday  Saturday
# ...        ...         ...     ...  ..            ...       ...
# 17199    17375  31/12/2012  Winter  19  Not a Holiday    Monday
# 17200    17376  31/12/2012  Winter  20  Not a Holiday    Monday
# 17201    17377  31/12/2012  Winter  21  Not a Holiday    Monday
# 17202    17378  31/12/2012  Winter  22  Not a Holiday    Monday
# 17203    17379  31/12/2012  Winter  23  Not a Holiday    Monday
#
#               workingday  weathersit  temp   hum  windspeed  popularity  \
# 0      Not a Working Day           1  24.0  0.81     0.0000    0.819931
# ...

# %%
Series1 = Series(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/4y/p5wbs2392ng1qdh47g8kk6x00000gn/T/ipykernel_14318/3993278511.py in ?()
# ----> 1 Series1 = Series(df)
#
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/series.py in ?(self, data, index, dtype, name, copy, fastpath)
#     471                 data = data.reindex(index, copy=copy)
#     472                 copy = False
#     473                 data = data._mgr
#     474         elif is_dict_like(data):
# --> 475             data, index = self._init_dict(data, index, dtype)
#     476             dtype = None
#     477             copy = False
#     478         elif isinstance(data, (SingleBlockManager, SingleArrayManager)):
#
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/series.py in ?(self, data, index, dtype)
# ...

# %%
Series
# Out:
# pandas.core.series.Series
